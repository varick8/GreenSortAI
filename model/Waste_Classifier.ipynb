# %%
import os

from keras.models import load_model  # TensorFlow is required for Keras to work
from PIL import Image, ImageOps  # Install pillow instead of PIL
import numpy as np
from sklearn.metrics import accuracy_score

# %%
# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

# %%
# Load the model
model = load_model("keras_model.h5", compile=False)

# %%
# Load the labels
class_names = open("labels.txt", "r").readlines()
category_to_index = {}
for class_name in class_names:
    index, name = class_name.split(' ')
    name = name[:-1]  # Menghapus karakter newline '\n' di akhir
    category_to_index[name] = int(index)

# %%
# Create the array of the right shape to feed into the keras model
# The 'length' or number of images you can put into the array is
# determined by the first position in the shape tuple, in this case 1
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

# %%
predictions = []
labels = []
root_dir = 'D:\DATA\COOLYEAH\Senpro\document\DATASET\Final\Valid'

for dir_ in os.listdir(root_dir):
    for j in os.listdir(os.path.join(root_dir, dir_)):
        image_path = os.path.join(root_dir, dir_, j)

        # Replace this with the path to your image
        image = Image.open(image_path).convert("RGB")

        # resizing the image to be at least 224x224 and then cropping from the center
        size = (224, 224)
        image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)

        # turn the image into a numpy array
        image_array = np.asarray(image)

        # Normalize the image
        normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1

        # Load the image into the array
        data[0] = normalized_image_array

        # Predicts the model
        prediction = model.predict(data)
        index = np.argmax(prediction)
        class_name = class_names[index]
        confidence_score = prediction[0][index]

        predictions.append(index)
        labels.append(category_to_index[dir_])

        # Print prediction and confidence score
        print("Class:", class_name[2:], end="")
        print("Confidence Score:", confidence_score)

print(accuracy_score(predictions, labels))
# Out:
# 1/1 [==============================] - 2s 2s/step
# Class: Anorganic
# Confidence Score: 0.9971271
# 1/1 [==============================] - 0s 54ms/step
# Class: Anorganic
# Confidence Score: 0.8360313
# 1/1 [==============================] - 0s 60ms/step
# Class: Anorganic
# Confidence Score: 0.9999292
# 1/1 [==============================] - 0s 48ms/step
# Class: Anorganic
# Confidence Score: 0.76239216
# 1/1 [==============================] - 0s 42ms/step
# Class: Anorganic
# Confidence Score: 0.92621243
# 1/1 [==============================] - 0s 48ms/step
# Class: Anorganic
# Confidence Score: 0.9786422
# 1/1 [==============================] - 0s 49ms/step
# Class: Anorganic
# Confidence Score: 0.6765741
# 1/1 [==============================] - 0s 54ms/step
# Class: Anorganic
# Confidence Score: 0.8472692
# 1/1 [==============================] - 0s 57ms/step
# Class: Anorganic
# Confidence Score: 0.95197743
# 1/1 [==============================] - 0s 51ms/step
# Class: B3
# Confidence Score: 0.65912205
# 1/1 [==============================] - 0s 47ms/step
# Class: Anorganic
# Confidence Score: 0.8020101
# 1/1 [==============================] - 0s 41ms/step
# Class: Anorganic
# Confidence Score: 0.586273
# 1/1 [==============================] - 0s 43ms/step
# Class: Anorganic
# Confidence Score: 0.71943146
# 1/1 [==============================] - 0s 36ms/step
# Class: Anorganic
# Confidence Score: 0.69678295
# 1/1 [==============================] - 0s 37ms/step
# Class: B3
# Confidence Score: 0.5346656
# 1/1 [==============================] - 0s 36ms/step
# Class: Anorganic
# Confidence Score: 0.9405533
# 1/1 [==============================] - 0s 38ms/step
# Class: Anorganic
# Confidence Score: 0.9626868
# 1/1 [==============================] - 0s 34ms/step
# Class: Anorganic
# Confidence Score: 0.84008336
# 1/1 [==============================] - 0s 37ms/step
# Class: Anorganic
# Confidence Score: 0.70700485
# 1/1 [==============================] - 0s 38ms/step
# Class: Anorganic
# Confidence Score: 0.84949917
# 1/1 [==============================] - 0s 39ms/step
# Class: Anorganic
# Confidence Score: 0.7236302
# 1/1 [==============================] - 0s 34ms/step
# Class: Anorganic
# Confidence Score: 0.8169658
# 1/1 [==============================] - 0s 35ms/step
# Class: Anorganic
# Confidence Score: 0.9073328
# 1/1 [==============================] - 0s 33ms/step
# Class: B3
# Confidence Score: 0.99775285
# 1/1 [==============================] - 0s 34ms/step
# Class: B3
# Confidence Score: 0.93362534
# 1/1 [==============================] - 0s 38ms/step
# Class: B3
# Confidence Score: 0.99143654
# 1/1 [==============================] - 0s 33ms/step
# Class: B3
# Confidence Score: 0.6918109
# 1/1 [==============================] - 0s 34ms/step
# Class: B3
# Confidence Score: 0.60258216
# 1/1 [==============================] - 0s 35ms/step
# Class: B3
# Confidence Score: 0.8666474
# 1/1 [==============================] - 0s 36ms/step
# Class: B3
# Confidence Score: 0.9681492
# 1/1 [==============================] - 0s 35ms/step
# Class: B3
# Confidence Score: 0.9252839
# 1/1 [==============================] - 0s 35ms/step
# Class: B3
# Confidence Score: 0.9770238
# 1/1 [==============================] - 0s 35ms/step
# Class: B3
# Confidence Score: 0.9650482
# 1/1 [==============================] - 0s 35ms/step
# Class: B3
# Confidence Score: 0.99715316
# 1/1 [==============================] - 0s 43ms/step
# Class: B3
# Confidence Score: 0.7167204
# 1/1 [==============================] - 0s 37ms/step
# Class: B3
# Confidence Score: 0.9743026
# 1/1 [==============================] - 0s 35ms/step
# Class: B3
# Confidence Score: 0.97483385
# 1/1 [==============================] - 0s 34ms/step
# Class: B3
# Confidence Score: 0.9856758
# 1/1 [==============================] - 0s 35ms/step
# Class: B3
# Confidence Score: 0.68227756
# 1/1 [==============================] - 0s 36ms/step
# Class: B3
# Confidence Score: 0.5749385
# 1/1 [==============================] - 0s 36ms/step
# Class: B3
# Confidence Score: 0.56002337
# 1/1 [==============================] - 0s 35ms/step
# Class: B3
# Confidence Score: 0.8552814
# 1/1 [==============================] - 0s 34ms/step
# Class: B3
# Confidence Score: 0.92145973
# 1/1 [==============================] - 0s 36ms/step
# Class: B3
# Confidence Score: 0.98633724
# 1/1 [==============================] - 0s 35ms/step
# Class: B3
# Confidence Score: 0.8854676
# 1/1 [==============================] - 0s 33ms/step
# Class: B3
# Confidence Score: 0.677708
# 1/1 [==============================] - 0s 33ms/step
# Class: B3
# Confidence Score: 0.97783023
# 1/1 [==============================] - 0s 36ms/step
# Class: Organic
# Confidence Score: 0.9984688
# 1/1 [==============================] - 0s 34ms/step
# Class: Organic
# Confidence Score: 0.99363685
# 1/1 [==============================] - 0s 33ms/step
# Class: Organic
# Confidence Score: 0.6586387
# 1/1 [==============================] - 0s 33ms/step
# Class: Anorganic
# Confidence Score: 0.5787673
# 1/1 [==============================] - 0s 32ms/step
# Class: Organic
# Confidence Score: 0.5250407
# 1/1 [==============================] - 0s 31ms/step
# Class: Anorganic
# Confidence Score: 0.5149356
# 1/1 [==============================] - 0s 33ms/step
# Class: Organic
# Confidence Score: 0.6937577
# 1/1 [==============================] - 0s 36ms/step
# Class: Organic
# Confidence Score: 0.9092859
# 1/1 [==============================] - 0s 37ms/step
# Class: Organic
# Confidence Score: 0.63658214
# 1/1 [==============================] - 0s 37ms/step
# Class: Organic
# Confidence Score: 0.5083895
# 1/1 [==============================] - 0s 43ms/step
# Class: Organic
# Confidence Score: 0.98011804
# 1/1 [==============================] - 0s 35ms/step
# Class: Organic
# Confidence Score: 0.8258604
# 1/1 [==============================] - 0s 33ms/step
# Class: Organic
# Confidence Score: 0.7734685
# 1/1 [==============================] - 0s 33ms/step
# Class: Anorganic
# Confidence Score: 0.5872733
# 1/1 [==============================] - 0s 33ms/step
# Class: Organic
# Confidence Score: 0.48647356
# 1/1 [==============================] - 0s 32ms/step
# Class: Anorganic
# Confidence Score: 0.5828422
# 0.9047619047619048
